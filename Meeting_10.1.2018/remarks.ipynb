# %% [markdown]
# ## Matplotlib notebook
#
#  - modify individual lines, points or arrays
#  - supports interactive plots

# %%
# %matplotlib notebook
from  ipywidgets import interact
import ipywidgets
import matplotlib.pyplot as plt
import numpy as np

# %%
f, ax = plt.subplots(1,1,figsize=(5,5))
a,b,c = .2,.2,.2
c = np.sqrt(a**2-b**2)

t = np.linspace(0, 2*np.pi, 100)

ax.plot( a*np.cos(t) , b*np.sin(t) )
ax.plot([c,-c],[0,0],'o')
l1,l2 = ax.lines
#plt.axis('equal')
#plt.grid(color='lightgray',linestyle='--')
@interact(a=ipywidgets.widgets.FloatSlider(min=0,max=1,value=0.2),\
          b=ipywidgets.widgets.FloatSlider(min=0,max=1,value=0.1))
def _(a,b):
    l1.set_data(a*np.cos(t) , b*np.sin(t))
# Out:
# <img src="data:image/png;base64,..." width="500">
# interactive(children=(FloatSlider(value=0.2, description='a', max=1.0), FloatSlider(value=0.1, description='b'…

# %% [markdown]
# ## K3d plots
#
# for interactive 3d

# %%
import k3d

# %%
plot  = k3d.plot()
plt_point = k3d.points([[-c,c,0]])
plt_line = k3d.line(np.stack([a*np.cos(t) , b*np.sin(t),np.zeros_like(t)]).T)
# Out:
# /Users/marcin/anaconda/envs/p3.6/lib/python3.6/site-packages/traittypes/traittypes.py:101: UserWarning: Given trait value dtype "float64" does not match required type "float32". A coerced copy has been created.
#   np.dtype(self.dtype).name))

# %%
plot += plt_line
plot += plt_point
plot
# Out:
# Plot(antialias=True, background_color=16777215, fps_meter=False, grid=[-1, -1, -1, 1, 1, 1], height=512, light…

# %%
plt_point.point_size =0.04

# %%
plot.camera_auto_fit = False
for t_ in t:
    plt_point.positions = np.stack([[-c,c,0],[a*np.cos(t_) , b*np.sin(t_),0]])
# Out:
# /Users/marcin/anaconda/envs/p3.6/lib/python3.6/site-packages/traittypes/traittypes.py:101: UserWarning: Given trait value dtype "float64" does not match required type "float32". A coerced copy has been created.
#   np.dtype(self.dtype).name))

# %%
np.stack([[-c,c,0],[.1,.2,.3]]).T
# Out:
# array([[-0. ,  0.1],
#        [ 0. ,  0.2],
#        [ 0. ,  0.3]])

# %% [markdown]
# ## ?

# %% [markdown]
# ## ?
